# %%
# pip3 install scikit-learn
# pip install pyreadr

from sklearn.linear_model import LinearRegression
import pandas as pd
import pyreadr

# %%
result = pyreadr.read_r('minorities_discrimination_survey.RData')

# %%
print(result.keys())
# Out:
# odict_keys(['min_dis'])

# %%
# Activate automatic conversion from R to pandas
df1 = result["min_dis"] # extract the pandas data frame for object df1

# %%
df1.head()
# Out:
#     za_nr             version                  doi  country  DEGURBA  ALTURBA  \
# 0  6703.0  1.0.0 (2020-07-29)  doi:10.4232/1.13514      1.0      1.0      NaN
# 1  6703.0  1.0.0 (2020-07-29)  doi:10.4232/1.13514      1.0      1.0      NaN
# 2  6703.0  1.0.0 (2020-07-29)  doi:10.4232/1.13514      1.0      1.0      NaN
# 3  6703.0  1.0.0 (2020-07-29)  doi:10.4232/1.13514      1.0      1.0      NaN
# 4  6703.0  1.0.0 (2020-07-29)  doi:10.4232/1.13514      1.0      1.0      NaN
#
#     C1   C2   C3  typint  ...  dis5_4_other  dis12overall10  dis5overall9  \
# 0  1.0  2.0  2.0     1.0  ...           0.0             1.0           1.0
# 1  1.0  2.0  2.0     1.0  ...           0.0             NaN           0.0
# 2  1.0  3.0  2.0     1.0  ...           0.0             1.0           1.0
# 3  1.0  3.0  2.0     1.0  ...           0.0             NaN           0.0
# 4  1.0  3.0  2.0     1.0  ...           0.0             NaN           0.0
#
# ...

# %%
# Assuming 'df' is your pandas DataFrame
variable_names = df1.columns.tolist()

# Print the list of variable names
print(variable_names)
# Out:
# ['za_nr', 'version', 'doi', 'country', 'DEGURBA', 'ALTURBA', 'C1', 'C2', 'C3', 'typint', 'IN02', 'IN03', 'numints', 'IN05', 'IN06', 'IN07', 'IN08', 'IN10', 'resp', 'Generation', 'HH01', 'HH02', 'HH02_1', 'HH03', 'HH04', 'HH05', 'HH06', 'HH07_1', 'HH07_2', 'HH07_3', 'HH07_4', 'HH08', 'HH09_1', 'HH10', 'HH10a', 'HH10b', 'HH10c', 'HH14', 'HH21_ROM', 'HH21_RUS', 'HH24', 'hch01', 'hch02', 'hch03', 'hch04_01', 'hch04_02', 'hch04_03', 'hch04_04', 'hch04_05', 'hch04_06', 'hch04_07', 'hch04_08', 'hch04_09', 'hch04_96', 'hch04_97', 'hch04_99', 'hch05_01', 'hch05_02', 'hch05_03', 'hch05_04', 'hch05_05', 'hch05_06', 'hch05_07', 'hch05_08', 'hch05_09', 'hch05_10', 'hch05_11', 'hch05_12', 'hch05_13', 'hch05_14', 'hch05_96', 'hch05_97', 'hch05_99', 'hch05a', 'hch05b', 'hch06', 'hch07_01', 'hch07_02', 'hch07_03', 'hch07_04', 'hch07_05', 'hch07_06', 'hch07_07', 'hch07_08', 'hch07_09', 'hch07_10', 'hch07_96', 'hch07_97', 'hch07_98', 'hch07_99', 'hch08', 'hch09', 'HLS01', 'HLS02', 'HLS04_1', 'HLS04_2',
# ...
